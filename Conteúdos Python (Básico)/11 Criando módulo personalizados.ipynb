# %% [markdown]
# Criar bibliotecas com funções úteis e constantes que utilizamos.
#
# A lógica seria a mesma de uma biblioteca math ou random. Teremos funções que criaremos e chamaremos através da biblioteca.
#
# - Acessamos o Anaconda > Spyder > File > New File > Salvamos > Vamos para o Colab e carregamos o arquivos (ícone files) > Upload do arquivo
#
# ```
# if string == string[::-1]
# ```
# - string é a string original.
# - [ indica o início de um slice.
# - : o primeiro : indica o início do slice (começa do início da string).
# - : o segundo : indica o fim do slice (vai até o final da string).
# - -1 é o "step" ou passo. Um passo de -1 significa que você está percorrendo a string de trás para a frente, um caractere por vez.
#
# ![image.png](data:image/png;base64,...)

# %%
import utilitarios as ut

print(ut.soma(3,2,1))
print(ut.mult(4,2,1))
print(ut.isPalindromo('joo'))
print(ut.isPalindromo('jooj'))
# Out:
# 6
# 8
# False
# True
