# %% [markdown]
# 1- Ler dois números inteiros, executar e mostrar o resultado das seguintes operações: adição, subtração, multiplicação e divisão

# %%
print('========================================')
print('============= CALCULADORA ==============')
print('========================================\n')

num_int01 = int(input('Informe o primeiro número: '))
num_int02 = int(input('Informe o segundo número: '))

print('\n----------------------------------------')
print('-------------- RESULTADOS --------------')
print('----------------------------------------\n')

print(f'- A soma de {num_int01} com {num_int02} foi de {num_int01 + num_int02}')
print(f'- A subtração de {num_int01} por {num_int02} foi de {num_int01 - num_int02}')
print(f'- A multiplicação de {num_int01} por {num_int02} foi de {num_int01 * num_int02}')

div = num_int01 / num_int02

print('- A divisão de {} por {} foi de {}'.format(num_int01, num_int02, round(div, 2))) #informando o arredondamento para duas casas após a vírgula
print(f'- A divisão inteira de {num_int01} por {num_int02} foi de {num_int01 // num_int02}')
print(f'- O resto da divisão de {num_int01} por {num_int02} foi de {num_int01 % num_int02}')
# Out:
# ...
# ============= CALCULADORA ==============
# ...
#
# Informe o primeiro número: 86
# Informe o segundo número: 3
#
# ----------------------------------------
# -------------- RESULTADOS --------------
# ----------------------------------------
#
# - A soma de 86 com 3 foi de 89
# - A subtração de 86 por 3 foi de 83
# - A multiplicação de 86 por 3 foi de 258
# - A divisão de 86 por 3 foi de 28.67
# - A divisão inteira de 86 por 3 foi de 28
# - O resto da divisão de 86 por 3 foi de 2

# %% [markdown]
# 2- Efetuar o cálculo da quantidade de litros de combustível gasto em uma viagem, utilizando um automóvel que faz 12 Km por litro. Para obter o cálculo, o usuário deve fornecer o tempo gasto na viagem e a velocidade média durante ela. Desta forma, será possível obter a distância percorrida com a fórmula DISTANCIA = TEMPO * VELOCIDADE. Tendo o valor da distância, basta calcular a quantidade de litros de combustível utilizada na viagem, com a fórmula: LITROS_USADOS = DISTANCIA / 12. O programa deve apresentar os valores da velocidade média, tempo gasto na viagem, a distância percorrida e a quantidade de litros utilizada na viagem

# %%
print('========================================')
print('=========== INFOS DE VIAGEM ============')
print('========================================\n')

km_por_litro = 12 #constante padrão para a Km/L de um carro

tempo_gasto_viagem = float(input('Informe o tempo gasto em viagem (horas): '))
velocidade_media_viagem = float(input('Informe a velocidade média na viagem (km/h): '))
22
distancia = tempo_gasto_viagem * velocidade_media_viagem
litros_usados = round(distancia / km_por_litro, 2)

print('\n----------------------------------------')
print('-------------- RESULTADOS --------------')
print('----------------------------------------\n')

print(f'- A velocidade média foi de {velocidade_media_viagem} km/h\n- O tempo gasto em viagem foi de {tempo_gasto_viagem} h/min\n- A distância percorrida foi de {distancia} km\n- A quantidade de litros usados foi de {litros_usados} l')
# Out:
# ...
# =========== INFOS DE VIAGEM ============
# ...
#
# Informe o tempo gasto em viagem (horas): 3
# Informe a velocidade média na viagem (km/h): 90
#
# ----------------------------------------
# -------------- RESULTADOS --------------
# ----------------------------------------
#
# - A velocidade média foi de 90.0 km/h
# - O tempo gasto em viagem foi de 3.0 h/min
# - A distância percorrida foi de 270.0 km
# - A quantidade de litros usados foi de 22.5 l
