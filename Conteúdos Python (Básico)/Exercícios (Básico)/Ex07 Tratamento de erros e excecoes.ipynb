# %% [markdown]
# # Crie uma lista vazia e faça a leitura de dois valores do tipo float, colocando cada um dos valores nas primeiras posições da lista (o valor1 ficará na posição 0 da lista e o valor2 ficará na posição 1 da lista). Faça a divisão dos dois valores e trate as seguintes exceções:
# - ValueError: se o usuário digitar um caracter
# - ZeroDivisionError: se o usuário digitar zero e ocorrer erro na divisão
# - IndexError: caso a divisão seja feita levando em consideração posições que não existem na lista
# - KeyboardInterrupt: caso o usuário interrompa a execução
# > Mostre uma mensagem personalizada na ocorrência de cada um desses erros

# %%
lista = []

while True:
  try:
    for i in range(0,2):
      lista.append(float(input('Digite um número qualquer, inteiro ou não: ')))
    divisao = lista[0] / lista[1]

  except ValueError:
    print('---')
    print('ValueError: O valor digitado não foi um número.')
    print('---')
    lista.clear()

  except ZeroDivisionError:
    print('---')
    print('ZeroDivisionError: Não é possível dividir por zero.')
    print('---')
    lista.clear()

  except IndexError:
    print('---')
    print('Não é possível o acesso ao índice.')
    print('---')
    lista.clear()

  except KeyboardInterrupt:
    print('---')
    print('O usuário interrompeu a execução.')
    print('---')
    break

  else:
    print('---')
    print(f'A divisão de {lista[0]} por {lista[1]} é {divisao}')
    break
# Out:
# Digite um número qualquer, inteiro ou não: 25
# Digite um número qualquer, inteiro ou não: i
# ---
# ValueError: O valor digitado não foi um número.
# ---
# Digite um número qualquer, inteiro ou não: 45
# Digite um número qualquer, inteiro ou não: 0
# ---
# ZeroDivisionError: Não é possível dividir por zero.
# ---
# Digite um número qualquer, inteiro ou não: j
# ---
# ValueError: O valor digitado não foi um número.
# ---
# Digite um número qualquer, inteiro ou não: 65
# Digite um número qualquer, inteiro ou não: 25.3
# ---
# A divisão de 65.0 por 25.3 é 2.569169960474308
