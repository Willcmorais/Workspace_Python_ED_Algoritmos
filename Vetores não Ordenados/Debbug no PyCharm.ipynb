# %% [markdown]
# # Debbug no PyCharm
#
# - Selecionar a linha -> Run -> Toggle Breakpoint -> Line Breakpoint -> Run -> Debbug.
#
# - Botão step over: Vai executar.
#
# - Botão step in: Vai entrar na função.
